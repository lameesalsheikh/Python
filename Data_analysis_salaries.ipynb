# %% [markdown]
# <a href="https://colab.research.google.com/github/lameesalsheikh/Python/blob/main/Data_analysis_salaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Salaries.csv")
df.head(3)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3  ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN

# %%
df.drop(columns="Status",axis=1,inplace=True)
df.drop(columns="Notes",axis=1,inplace=True)
df.head(2)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
#
#    Year         Agency
# 0  2011  San Francisco
# 1  2011  San Francisco

# %%
df.drop(columns="Id",axis=1,inplace=True)
df.head(1)
# Out:
#      EmployeeName                                        JobTitle    BasePay  \
# 0  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
#
#    OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 0          0.0  400184.25       NaN  567595.43         567595.43  2011
#
#           Agency
# 0  San Francisco

# %%
df.to_csv("/content/Salaries_clean.csv")
df1=pd.read_csv("/content/Salaries_clean.csv")
df1.head(2)
# Out:
#    Unnamed: 0    EmployeeName                                        JobTitle  \
# 0           0  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1           1    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
#
#    Year         Agency
# 0  2011  San Francisco
# 1  2011  San Francisco

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Agency            148654 non-null  object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 12.5+ MB

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1[~df1.duplicated()]
# Out:
#         Unnamed: 0       EmployeeName  \
# 0                0     NATHANIEL FORD
# 1                1       GARY JIMENEZ
# 2                2     ALBERT PARDINI
# 3                3  CHRISTOPHER CHONG
# 4                4    PATRICK GARDNER
# ...            ...                ...
# 148649      148649      Roy I Tillery
# 148650      148650       Not provided
# 148651      148651       Not provided
# 148652      148652       Not provided
# 148653      148653          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay',
#        'OtherPay', 'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year',
#        'Agency'],
#       dtype='object')

# %%
df1.drop(columns="Unnamed: 0",axis=1,inplace=True)

# %%
df1.head(1)
# Out:
#      EmployeeName                                        JobTitle    BasePay  \
# 0  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
#
#    OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 0          0.0  400184.25       NaN  567595.43         567595.43  2011
#
#           Agency
# 0  San Francisco

# %%
df1.isnull().sum()
# Out:
# EmployeeName            0
# JobTitle                0
# BasePay               609
# OvertimePay             4
# OtherPay                4
# Benefits            36163
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# Agency                  0
# dtype: int64

# %%
df1["Benefits"]=df1["Benefits"].fillna(0)
df1
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
df1.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       Benefits  \
# count  148045.000000  148650.000000  148650.000000  148654.000000
# mean    66325.448840    5066.059886    3648.767297   18924.232839
# std     42764.635495   11454.380559    8056.601866   17165.279495
# min      -166.010000      -0.010000   -7058.590000     -33.890000
# 25%     33588.200000       0.000000       0.000000       0.000000
# 50%     65007.450000       0.000000     811.270000   23214.020000
# 75%     94691.050000    4658.175000    4236.065000   33468.980000
# max    319275.010000  245131.880000  400184.250000   96570.660000
#
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# ...

# %%
df1.shape
# Out:
# (148654, 10)

# %%
df1.dtypes
# Out:
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Agency               object
# dtype: object

# %%
table = pd.pivot_table(df1, values='TotalPay', index=['JobTitle'] , aggfunc="count")
table
# Out:
#                                                 TotalPay
# JobTitle
# ACCOUNT CLERK                                         83
# ACCOUNTANT                                             5
# ACCOUNTANT INTERN                                     48
# ACPO,JuvP, Juv Prob (SFERS)                            1
# ACUPUNCTURIST                                          1
# ...                                                  ...
# X-RAY LABORATORY AIDE                                 26
# X-Ray Laboratory Aide                                100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS         1
# Youth Comm Advisor                                     4
# ZOO CURATOR                                            1
#
# [2159 rows x 1 columns]

# %%
table = pd.pivot_table(df1, values='TotalPay', index=['JobTitle'] , aggfunc="sum")
table
# Out:
#                                                   TotalPay
# JobTitle
# ACCOUNT CLERK                                   3654960.14
# ACCOUNTANT                                       237146.34
# ACCOUNTANT INTERN                               1393523.66
# ACPO,JuvP, Juv Prob (SFERS)                       62290.78
# ACUPUNCTURIST                                     67594.40
# ...                                                    ...
# X-RAY LABORATORY AIDE                           1370352.89
# X-Ray Laboratory Aide                           5082394.27
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    53632.87
# Youth Comm Advisor                               165657.23
# ZOO CURATOR                                       66686.56
#
# [2159 rows x 1 columns]

# %%
df1_cat=df.select_dtypes(include="object")
df1_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   EmployeeName  148654 non-null  object
#  1   JobTitle      148654 non-null  object
#  2   Agency        148654 non-null  object
# dtypes: object(3)
# memory usage: 3.4+ MB

# %%
df1['JobTitle'].value_counts()
# Out:
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: JobTitle, Length: 2159, dtype: int64

# %%
df1['Agency'].value_counts()
# Out:
# San Francisco    148654
# Name: Agency, dtype: int64

# %%
df1_flo=df.select_dtypes(include="float")
df1_flo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   BasePay           148045 non-null  float64
#  1   OvertimePay       148650 non-null  float64
#  2   OtherPay          148650 non-null  float64
#  3   Benefits          112491 non-null  float64
#  4   TotalPay          148654 non-null  float64
#  5   TotalPayBenefits  148654 non-null  float64
# dtypes: float64(6)
# memory usage: 6.8 MB

# %%
df1_year=df.select_dtypes(include="int")
df1_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Year    148654 non-null  int64
# dtypes: int64(1)
# memory usage: 1.1 MB

# %%
heat=df1.corr()
heat
# Out:
# <ipython-input-24-d685d327f781>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heat=df1.corr()
#                    BasePay  OvertimePay  OtherPay  Benefits  TotalPay  \
# BasePay           1.000000     0.266740  0.285655  0.653227  0.954494
# OvertimePay       0.266740     1.000000  0.316592  0.226165  0.504859
# OtherPay          0.285655     0.316592  1.000000  0.160334  0.470496
# Benefits          0.653227     0.226165  0.160334  1.000000  0.632202
# TotalPay          0.954494     0.504859  0.470496  0.632202  1.000000
# TotalPayBenefits  0.946595     0.467981  0.422341  0.781963  0.977313
# Year              0.033751     0.027887 -0.002499  0.461408  0.032090
#
#                   TotalPayBenefits      Year
# BasePay                   0.946595  0.033751
# OvertimePay               0.467981  0.027887
# ...

# %%
top5=df1['JobTitle'].value_counts().head(5)
top5.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
avg=df1.groupby('Year').mean()['BasePay']
avg.plot(kind = 'bar')
# Out:
# <ipython-input-26-860423f65060>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg=df1.groupby('Year').mean()['BasePay']
# <Axes: xlabel='Year'>

# %%
import matplotlib.pyplot as plt

df2 = pd.DataFrame(df1)

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(df['JobTitle'], df['TotalPay'], color='skyblue')
plt.xlabel('Job Title')
plt.ylabel('Total Pay')
plt.title('Total Pay for Each Job Title')
plt.xticks(rotation=45, ha='right')

# Show the bar plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(df1['TotalPay'], kde=True, color='skyblue')
plt.title('Histogram and KDE for Total Pay')
plt.xlabel('Total Pay')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a boxplot for 'Base Salary'
plt.figure(figsize=(8, 6))
plt.boxplot(df1_flo['TotalPay'])
plt.title('Boxplot of Total pay')
plt.ylabel('Total pay')

# Show the boxplot
plt.show()

# %%
plt.figure(figsize=(10, 6))
heatmap_data = heat
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt='g')
plt.title('Heatmap of Data farame')
plt.show()

# %%
other=df1['OtherPay'].sum()
other
# Out:
# 542389258.6700001

# %%
over=df1['OvertimePay'].sum()
over
# Out:
# 753069802.1199998

# %%
otherratio=(other/df1['TotalPay'].sum())*100
otherratio
# Out:
# 4.879966567538591

# %%
overratio=(over/df1['TotalPay'].sum())*100
overratio
# Out:
# 6.775494533907084

# %%
greater = df[df["TotalPay"] >200000].describe()
greater
# Out:
#              BasePay    OvertimePay       OtherPay      Benefits  \
# count    2008.000000    2008.000000    2008.000000   1748.000000
# mean   162999.878053   38700.522356   24161.464124  50495.836768
# std     46047.879935   38967.777666   31457.169195  11661.844778
# min     15158.500000       0.000000       0.000000   6116.190000
# 25%    128091.802500       0.000000   10096.435000  42400.300000
# 50%    155174.465000   35285.360000   17777.010000  48876.540000
# 75%    200557.740000   70805.710000   25440.510000  57633.910000
# max    319275.010000  245131.880000  400184.250000  96570.660000
#
#             TotalPay  TotalPayBenefits         Year
# count    2008.000000       2008.000000  2008.000000
# mean   225861.864532     269819.395742  2012.808765
# std     29370.247890      37110.873149     0.994896
# min    200011.000000     200176.680000  2011.000000
# 25%    206780.482500     251056.575000  2012.000000
# 50%    216670.655000     264293.665000  2013.000000
# ...

# %%
gro = df[df["TotalPay"] >200000].groupby('JobTitle').sum()
gro
# Out:
# <ipython-input-36-80f7dd13d1fa>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gro = df[df["TotalPay"] >200000].groupby('JobTitle').sum()
#                                                      BasePay  OvertimePay  \
# JobTitle
# ADMINISTRATOR, SFGH MEDICAL CENTER                 245124.44         0.00
# ANESTHETIST                                       1592859.12     48008.47
# ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)   372914.15    107989.45
# ASSISTANT DEPUTY CHIEF II                          629180.63     22308.84
# ASSISTANT MEDICAL EXAMINER                         772531.51      1257.37
# ...                                                      ...          ...
# Transit Manager 2                                   98211.01         0.00
# ...

# %%
des = df[df["TotalPay"] >200000].groupby('JobTitle').describe()
des
# Out:
#                                                  BasePay                 \
#                                                    count           mean
# JobTitle
# ADMINISTRATOR, SFGH MEDICAL CENTER                   1.0  245124.440000
# ANESTHETIST                                          8.0  199107.390000
# ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)     2.0  186457.075000
# ASSISTANT DEPUTY CHIEF II                            4.0  157295.157500
# ASSISTANT MEDICAL EXAMINER                           3.0  257510.503333
# ...                                                  ...            ...
# Transit Manager 2                                    1.0   98211.010000
# Transit Supervisor                                  11.0   94367.091818
# Undersheriff                                         1.0  189063.040000
# WIRE ROPE CABLE MAINTENANCE MECHANIC                 1.0   77916.000000
# Wire Rope Cable Maint Sprv                           1.0   88634.010000
#
# ...
